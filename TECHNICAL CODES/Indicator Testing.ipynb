# %%
from pgcbacktest.TechnicalAnalysis import *
index_df = pd.read_csv(r"C:\Users\jnv22\OneDrive\Desktop\NIFTY 50.csv", parse_dates=['datetime'])

# %%
# Moving Average Crossover
signal_df = moving_cross_over(index_df, 'NORMAL', 20, 'NORMAL', 50)
test_df = signal_df[signal_df['datetime'].dt.date == datetime.date(2024,12,31)]
plot_moving_crossover_signals(test_df)

# %%
# SuperTrend
signal_df = supertrend(index_df, period=10, multiplier=3)
test_df = signal_df[signal_df['datetime'].dt.date == datetime.date(2024,12,31)]
plot_supertrend_signals(test_df)

# %%
# Relative Strength Index (RSI)
signal_df = rsi(index_df, period=14, upper=70, lower=30)
test_df = signal_df[signal_df['datetime'].dt.date == datetime.date(2024,12,31)]
plot_rsi_signals(test_df)

# %%
# Moving Average Convergence Divergence (MACD)
signal_df = macd(index_df, fast=12, slow=26, signal=9)
test_df = signal_df[signal_df['datetime'].dt.date == datetime.date(2024,12,31)]
plot_macd(test_df)
